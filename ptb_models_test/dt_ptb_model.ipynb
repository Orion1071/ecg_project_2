# %%
import tensorflow as tf 
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

import numpy as np
import matplotlib.pyplot as plt

# %%
X = pickle.load(open("C:/Users/sanda/Documents/ptb_xl/ptb_xl_v2_pcl/all_X_ptbxl.pcl", 'rb'))
y = np.array(pickle.load(open("C:/Users/sanda/Documents/ptb_xl/ptb_xl_v2_pcl/all_y_ptbxl.pcl", 'rb'))).astype('int')

# %%
print(X.shape)
print(y.shape)
print(np.unique(y, return_counts=True))
# Out:
# (21837, 1000, 12)
# (21837,)
# (array([0, 1, 2, 3, 4]), array([9495, 4140, 5250, 2547,  405], dtype=int64))

# %%
X_train, X_test,y_train,y_test = train_test_split(X[:,:,1], y, test_size=0.33, random_state=42)

# %%
print(X_train[0].shape)
print(y_test.shape)
# Out:
# (1000,)
# (7207,)

# %%
dt = DecisionTreeClassifier()

dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print()

# %%
predict = dt.predict(X_test)
print(accuracy_score(y_test, predict))
confusion_matrixs = confusion_matrix(y_test, predict)
cf = ConfusionMatrixDisplay(confusion_matrixs)
cf.plot()
# Out:
# 0.36908561121132233
